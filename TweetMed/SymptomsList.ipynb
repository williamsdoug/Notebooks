# %% [markdown]
# #List of medical symptoms
#
# ###Scope
# - Download standard symptime list
# - Determine synonyms or layman's terms
#
# ###Data Sources:
#
# - Wikipedia
#  - [List of medical symptoms](http://en.wikipedia.org/wiki/List_of_medical_symptoms)
#  - [List of ICD-9 codes 780–799: symptoms, signs, and ill-defined conditions](http://en.wikipedia.org/wiki/List_of_ICD-9_codes_780–799:_symptoms,_signs,_and_ill-defined_conditions)
#  - [ICD-10 Chapter XVIII: Symptoms, signs and abnormal clinical and laboratory findings](http://en.wikipedia.org/wiki/ICD-10_Chapter_XVIII:_Symptoms,_signs_and_abnormal_clinical_and_laboratory_findings#.28R00.E2.80.93R09.29_Circulatory_and_respiratory_systems)
# - FamilyDoctor
#  - [Search by Symptom](http://familydoctor.org/familydoctor/en/health-tools/search-by-symptom.html)

# %% [markdown]
# #Imports

# %%
from pprint import pprint
from pattern.web import Wikipedia
from pattern.en import wordnet
import pickle

# %% [markdown]
# #Constants

# %% [markdown]
# #Code

# %%
def getTermsFromWikipedia(article_name, selected_sections=['illness', 'the list']):
    article = Wikipedia().search('List of medical symptoms')
    all_terms = []
    for section in article.sections:
        if section.title.strip().lower() not in selected_sections:
            continue

        print repr(' ' * section.level + section.title), 
        print 'Links:', len(section.links)
        all_terms += [str(x.split('(')[0]).lower().strip() for x in section.links]

    print 'total terms:', len(all_terms)
    all_terms = sorted(list(set(all_terms)))  # dedupe
    print 'terms after dedupe', len(all_terms)
    return all_terms

# %%
def show_synonyms(wordlist, threshold=1):
    for term in wordlist:
        for s in wordnet.synsets(term):
            if len(s.synonyms) > threshold:
                print "'{}'".format(term), [str(x) for x in s.synonyms if x != term]

# %%
def show_self_synonyms(wordlist):
    for term in wordlist:
        for s in wordnet.synsets(term):
            if len(s.synonyms) == 1:
                print term, [str(x) for x in s.synonyms]

# %%
def no_synonym_terms(wordlist):
    return [term for term in wordlist if not wordnet.synsets(term)]

# %% [markdown]
# #Analysis

# %%
all_terms = getTermsFromWikipedia('List of medical symptoms')
# Out:
# u'  Illness' Links: 40
# u' The List' Links: 149
# total terms: 189
# terms after dedupe 167

# %% [raw]
# show_self_synonyms(all_terms)

# %%
# terms with no synonym
no_synonym_terms(all_terms)
# Out:
# ['-phobia',
#  'abdominal pain',
#  'acalculia',
#  'akathisia',
#  'altered state of consciousness',
#  'amaurosis fugax',
#  'amusia',
#  'anosognosia',
#  'antepartum haemorrhage',
#  'back pain',
#  'bloating',
#  'blood in stool',
#  'bloody show',
#  'blurred vision',
#  'bradykinesia',
#  'bradypnea',
#  'cataplexy',
#  'chills',
#  'chronic pelvic pain',
#  "dalrymple's sign",
#  'drug overdose',
#  'dysdiadochokinesia',
#  'dysgeusia',
#  'dyspareunia',
#  'dystonia',
#  'fainting',
#  'fecal incontinence',
#  'hemiballismus',
#  'homicidal ideation',
#  'hypoventilation',
#  'icd-10',
#  'loss of appetite',
#  'mucopurulent discharge',
#  'muscle weakness',
#  'pathologic nystagmus',
#  'pleuritic chest pain',
#  'proctalgia fugax',
#  'prosopagnosia',
#  'rectal pain',
#  'retrograde ejaculation',
#  'self-injury',
#  'strangury',
#  'suicidal ideation',
#  'tachypnea',
#  'urinary frequency',
#  'weight gain',
#  'weight loss']

# %%
# Find synonyms
show_synonyms(all_terms, threshold=0)
# Out:
# 'abrasion' ['scratch', 'scrape', 'excoriation']
# 'abrasion' ['attrition', 'corrasion', 'detrition']
# 'abrasion' ['grinding', 'attrition', 'detrition']
# 'acrophobia' []
# 'agnosia' []
# 'agoraphobia' []
# 'akinesia' ['akinesis']
# 'alexia' ['visual aphasia', 'word blindness']
# 'alopecia' []
# 'amaurosis' []
# 'amnesia' ['memory loss', 'blackout']
# 'anasarca' []
# 'anhedonia' []
# 'anomic aphasia' ['nominal aphasia', 'anomia', 'amnesic aphasia', 'amnestic aphasia']
# 'anorexia' []
# 'anosmia' []
# 'anxiety' ['anxiousness']
# 'anxiety' []
# 'aphasia' []
# 'apnea' []
# 'apraxia' []
# 'arachnophobia' []
# 'arrhythmia' ['cardiac arrhythmia']
# 'asthenia' ['astheny']
# 'ataxia' ['ataxy', 'dyssynergia', 'motor ataxia']
# 'belching' []
# 'belching' ['belch', 'burp', 'burping', 'eructation']
# 'bleeding' ['hemorrhage', 'haemorrhage']
# 'blindness' ['sightlessness', 'cecity']
# 'blister' []
# 'blister' []
# 'blister' ['bulla', 'bleb']
# 'bradycardia' []
# 'bruise' ['contusion']
# 'cachexia' ['cachexy', 'wasting']
# 'chest pain' []
# 'childbirth' ['childbearing', 'accouchement', 'vaginal birth']
# 'chorea' ['canine chorea']
# 'chorea' []
# 'claudication' ['lameness', 'limping', 'gimp', 'gimpiness', 'gameness']
# 'claustrophobia' []
# 'constipation' ['irregularity']
# 'constipation' ['stultification', 'impairment', 'deadening']
# 'convulsion' ['paroxysm', 'fit']
# 'convulsion' []
# 'convulsion' ['turmoil', 'upheaval']
# 'convulsion' []
# 'cough' ['coughing']
# 'cramp' ['spasm', 'muscle spasm']
# 'cramp' []
# 'cramp' ['cramp iron']
# 'deformity' ['malformation', 'misshapenness']
# 'deformity' ['disfigurement', 'disfiguration']
# 'depression' []
# 'depression' ['slump', 'economic crisis']
# 'depression' ['natural depression']
# 'depression' []
# 'depression' ['Depression', 'Great Depression']
# 'depression' ['low']
# 'depression' ['depressive disorder', 'clinical depression']
# 'depression' ['impression', 'imprint']
# 'depression' []
# 'depression' []
# 'diaphoresis' ['perspiration', 'sweating', 'sudation', 'hidrosis']
# 'diarrhea' ['diarrhoea', 'looseness of the bowels', 'looseness']
# 'diplopia' ['double vision']
# 'dizziness' ['giddiness', 'lightheadedness', 'vertigo']
# 'dry mouth' ['xerostomia']
# 'dysarthria' []
# 'dysgraphia' []
# 'dyspepsia' ['indigestion', 'stomach upset', 'upset stomach']
# 'dysphagia' []
# 'dyspnea' ['dyspnoea']
# 'dysuria' []
# 'edema' ['oedema', 'hydrops', 'dropsy']
# 'epistaxis' ['nosebleed']
# 'euphoria' ['euphory']
# 'exophthalmos' []
# 'fatigue' ['weariness', 'tiredness']
# 'fatigue' []
# 'fatigue' []
# 'fatigue' ['fatigue duty']
# 'fever' ['febrility', 'febricity', 'pyrexia', 'feverishness']
# 'fever' []
# 'flatulence' ['flatulency', 'gas']
# 'flatulence' ['turgidity', 'turgidness']
# 'haematemesis' ['hematemesis']
# 'hallucination' []
# 'hallucination' ['delusion']
# 'hallucination' []
# 'headache' ['concern', 'worry', 'vexation']
# 'headache' ['head ache', 'cephalalgia']
# 'hearing impairment' ['hearing disorder']
# 'hematochezia' ['haematochezia']
# 'hematuria' ['haematuria']
# 'hemiplegia' ['unilateral paralysis']
# 'hemoptysis' ['haemoptysis']
# 'hirsutism' ['hirsuteness']
# 'hyperhidrosis' ['hyperidrosis', 'polyhidrosis']
# 'hyperthermia' ['hyperthermy']
# 'hyperventilation' []
# 'hypothermia' []
# 'impotence' ['powerlessness', 'impotency']
# 'impotence' ['impotency']
# 'infertility' ['sterility']
# 'insomnia' []
# 'itch' ['scabies']
# 'itch' ['urge']
# 'itch' ['itchiness', 'itching']
# 'jaundice' ['icterus']
# 'jaundice' ['bitterness', 'acrimony', 'acerbity', 'tartness', 'thorniness']
# 'malaise' ['unease', 'uneasiness']
# 'mania' ['passion', 'cacoethes']
# 'mania' ['manic disorder']
# 'melena' ['melaena']
# 'miosis' ['meiosis', 'reduction division']
# 'miosis' ['light reflex', 'pupillary reflex', 'myosis']
# 'miscarriage' ['abortion']
# 'miscarriage' ['spontaneous abortion', 'stillbirth']
# 'mydriasis' []
# 'nausea' ['sickness']
# 'nausea' []
# 'odynophagia' []
# 'otalgia' ['earache']
# 'pain' ['hurting']
# 'pain' ['painfulness']
# 'pain' ['pain sensation', 'painful sensation']
# 'pain' ['pain in the neck', 'nuisance']
# 'pain' ['annoyance', 'bother', 'botheration', 'infliction', 'pain in the neck', 'pain in the ass']
# 'palpitation' []
# 'palpitation' ['shaking', 'shakiness', 'trembling', 'quiver', 'quivering', 'vibration']
# 'paralysis' ['palsy']
# 'paranoia' []
# 'paresthesia' ['paraesthesia']
# 'persecution' []
# 'perspiration' ['sweat', 'sudor']
# 'perspiration' ['sweating', 'diaphoresis', 'sudation', 'hidrosis']
# 'phobia' ['phobic disorder', 'phobic neurosis']
# 'polyuria' []
# 'pyrexia' ['fever', 'febrility', 'febricity', 'feverishness']
# 'pyrosis' ['heartburn']
# 'rash' ['roseola', 'efflorescence', 'skin rash']
# 'rash' ['blizzard']
# 'rigor' ['asperity', 'grimness', 'hardship', 'rigour', 'severity', 'severeness', 'rigorousness', 'rigourousness']
# 'rigor' ['cogency', 'validity', 'rigour']
# 'rigor' ['severity', 'severeness', 'harshness', 'rigour', 'rigorousness', 'rigourousness', 'inclemency', 'hardness', 'stiffness']
# 'sciatica' []
# 'shivering' ['chill']
# 'somnolence' ['sleepiness', 'drowsiness']
# 'sputum' ['phlegm']
# 'steatorrhea' []
# 'swelling' ['puffiness', 'lump']
# 'swelling' ['bulge', 'bump', 'hump', 'gibbosity', 'gibbousness', 'jut', 'prominence', 'protuberance', 'protrusion', 'extrusion', 'excrescence']
# 'swelling' ['intumescence', 'intumescency']
# 'tachycardia' []
# 'thirst' ['thirstiness']
# 'thirst' ['hunger', 'hungriness', 'thirstiness']
# 'tic' []
# 'tinnitus' []
# 'toothache' ['odontalgia']
# 'tremor' ['shudder']
# 'tremor' ['earth tremor', 'microseism']
# 'tremor' []
# 'tuberculosis' ['TB', 'T.B.']
# 'urinary incontinence' ['enuresis']
# 'urinary retention' []
# 'urticaria' ['urtication', 'hives', 'nettle rash']
# 'vagina' []
# 'vaginismus' []
# 'vertigo' ['dizziness', 'giddiness', 'lightheadedness']
# 'vomiting' ['vomit', 'emesis', 'regurgitation', 'disgorgement', 'puking']
# 'wound' ['lesion']
# 'wound' ['injury', 'combat injury']
# 'wound' []
# 'wound' ['wounding']
# 'xerostomia' ['dry mouth']

# %% [markdown]
# #Manually scrub terms from Wikipedia

# %%
selected_terms = [
 'pain',
 'bloating',
 'stool',
 'bloody',
 'blurred',
 'chills',
 'fainting',
 'fecal',
 'incontinence',
 'hypoventilation',
 'appetite',
 'muscle',
 'weakness',
 'rectal',
 'injury',
 'urine',
 'weight gain',
 'weight loss']

# %%
selected_terms2 = [
'amnesia','memory loss', 'blackout',
'anorexia',
'anxiety', 'anxiousness',
'apnea',
'arrhythmia',
'belching','belch', 'burp', 'burping',
'bleeding','hemorrhage', 'haemorrhage',
'blindness',
'blister',
'bruise','contusion',
'wasting',
'chorea',
'lameness', 'limping', 'gimp',
'claustrophobia',
'constipation', 'irregularity',
'convulsion', 'fit',
'cough', 'coughing', 
'cramp', 'spasm',
'deformity',
'depression', 'low', 'blue'
'perspiration', 'sweating',
'diarrhea','diarrhoea', 'bowels',
'double vision',
'dizziness', 'lightheadedness', 'vertigo',
'dry mouth',
'indigestion', 'stomach',
'edema', 'dropsy',
'nosebleed',
'fatigue', 'weariness', 'tiredness',
'fever',
'flatulence','flatulency', 'gas', 'turgid',
'hallucination','delusion',
'headache' 'ache',
'hearing', 
'hyperthermia',
'hyperventilation',
'hypothermia',
'impotence', 'impotency',
'infertility',
'insomnia',
'itch', 'scabies', 'itchiness', 'itching',
'jaundice',
'malaise',
'mania'
'miscarriage', 'stillbirth',
'nausea', 'sickness',
'earache',
'pain', 'hurting', 'painful',
'palpitation', 'shaking', 'shakiness', 'trembling', 'quiver', 'quivering', 'vibration',
'paralysis', 'palsy',
'paranoia', 
'perspiration', 'sweat',
'phobia', 'phobic',
'fever', 'feverishness',
'heartburn', 
'rash',
'stiffness', 
'sciatica', 
'shivering', 'chill', 
'somnolence', 'sleepiness', 'drowsiness', 
'sputum', 'phlegm', 
'swelling', 'puffiness', 'lump',
'thirst', 'thirstiness', 'hunger', 'hungriness',
'tic',
'tinnitus', 
'toothache', 
'tremor', 'shudder',
'tuberculosis', 'tb',
'urinary', 'incontinence', 
'hives', 
'vagina',
'vertigo', 'dizziness', 'lightheadedness',
'vomiting', 'vomit', 'puking',
'wound', 'lesion',
'dry mouth'
    ]

# %%
other_terms = ['bleed', 'ache', 'sore', 'dizzy', 'nausious', 'sick',
               'tingle', 'tingling', 'infection', 'pneumonia', 'throat', 'wheezing', 'gout']

# %%
combined_symptoms = sorted(list(set(selected_terms+selected_terms2+other_terms)))
print len(combined_symptoms)
combined_symptoms
# Out:
# 162
# ['ache',
#  'amnesia',
#  'anorexia',
#  'anxiety',
#  'anxiousness',
#  'apnea',
#  'appetite',
#  'arrhythmia',
#  'belch',
#  'belching',
#  'blackout',
#  'bleed',
#  'bleeding',
#  'blindness',
#  'blister',
#  'bloating',
#  'bloody',
#  'blueperspiration',
#  'blurred',
#  'bowels',
#  'bruise',
#  'burp',
#  'burping',
#  'chill',
#  'chills',
#  'chorea',
#  'claustrophobia',
#  'constipation',
#  'contusion',
#  'convulsion',
#  'cough',
#  'coughing',
#  'cramp',
#  'deformity',
#  'delusion',
#  'depression',
#  'diarrhea',
#  'diarrhoea',
#  'dizziness',
#  'dizzy',
#  'double vision',
#  'dropsy',
#  'drowsiness',
#  'dry mouth',
#  'earache',
#  'edema',
#  'fainting',
#  'fatigue',
#  'fecal',
#  'fever',
#  'feverishness',
#  'fit',
#  'flatulence',
#  'flatulency',
#  'gas',
#  'gimp',
#  'gout',
#  'haemorrhage',
#  'hallucination',
#  'headacheache',
#  'hearing',
#  'heartburn',
#  'hemorrhage',
#  'hives',
#  'hunger',
#  'hungriness',
#  'hurting',
#  'hyperthermia',
#  'hyperventilation',
#  'hypothermia',
#  'hypoventilation',
#  'impotence',
#  'impotency',
#  'incontinence',
#  'indigestion',
#  'infection',
#  'infertility',
#  'injury',
#  'insomnia',
#  'irregularity',
#  'itch',
#  'itchiness',
#  'itching',
#  'jaundice',
#  'lameness',
#  'lesion',
#  'lightheadedness',
#  'limping',
#  'low',
#  'lump',
#  'malaise',
#  'maniamiscarriage',
#  'memory loss',
#  'muscle',
#  'nausea',
#  'nausious',
#  'nosebleed',
#  'pain',
#  'painful',
#  'palpitation',
#  'palsy',
#  'paralysis',
#  'paranoia',
#  'perspiration',
#  'phlegm',
#  'phobia',
#  'phobic',
#  'pneumonia',
#  'puffiness',
#  'puking',
#  'quiver',
#  'quivering',
#  'rash',
#  'rectal',
#  'scabies',
#  'sciatica',
#  'shakiness',
#  'shaking',
#  'shivering',
#  'shudder',
#  'sick',
#  'sickness',
#  'sleepiness',
#  'somnolence',
#  'sore',
#  'spasm',
#  'sputum',
#  'stiffness',
#  'stillbirth',
#  'stomach',
#  'stool',
#  'sweat',
#  'sweating',
#  'swelling',
#  'tb',
#  'thirst',
#  'thirstiness',
#  'throat',
#  'tic',
#  'tingle',
#  'tingling',
#  'tinnitus',
#  'tiredness',
#  'toothache',
#  'trembling',
#  'tremor',
#  'tuberculosis',
#  'turgid',
#  'urinary',
#  'urine',
#  'vagina',
#  'vertigo',
#  'vibration',
#  'vomit',
#  'vomiting',
#  'wasting',
#  'weakness',
#  'weariness',
#  'weight gain',
#  'weight loss',
#  'wheezing',
#  'wound']

# %%
pickle.dump( combined_symptoms, open( "symptoms.p", "wb" ))
